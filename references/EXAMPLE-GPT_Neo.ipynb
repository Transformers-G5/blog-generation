#      |████████████████████████████████| 1982.2 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1982177280 bytes == 0xf4586000 @  0x7f8c2a2b91e7 0x4b2590 0x4b261c 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6
# tcmalloc: large alloc 2477727744 bytes == 0x1dec96000 @  0x7f8c2a2ba615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x4bad99 0x4d3249
#      |████████████████████████████████| 1982.2 MB 2.8 kB/s
# Collecting torchvision==0.9.1+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.9.1%2Bcu111-cp37-cp37m-linux_x86_64.whl (17.6 MB)
#      |████████████████████████████████| 17.6 MB 58.3 MB/s
# Collecting torchaudio===0.8.1
#   Downloading torchaudio-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 14.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1+cu111) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1+cu111) (1.21.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.9.1+cu111) (7.1.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.8.1+cu111 which is incompatible.
# Successfully installed torch-1.8.1+cu111 torchaudio-0.8.1 torchvision-0.9.1+cu111

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 15.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 56.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 71.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1

# %%
from transformers import pipeline
# Out:
# Failed to start the Kernel.
#
# spawn /conda ENOENT.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# generator = pipeline('text-generation', model='EleutherAI/gpt-neo-2.7B') 
# generator = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B') 
generator = pipeline('text-generation', model='EleutherAI/gpt-neo-125M')
# Out:
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/526M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]

# %%
prompt = "The uprising of apple iphone"

# %%
res = generator(prompt, max_length=500, do_sample=True, temperature=0.9)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(res[0]['generated_text']) # 125M model
# Out:
# The uprising of apple iphone plants and the subsequent decline in the profitability of the device remain at high levels, as the cost of a device that is not designed to operate properly has been raised. This is the reason that the apple iphone plant is a significant source of pollution in the United States. In addition, there are the problems associated with the safety device itself, and the potential for damage to the plant's safety device, which are both a safety issue for the plant's users and the potential for disruption to surrounding areas.
# The present invention provides novel methods of providing a device that can be used for both the safe and the non-safe. The devices of this invention may be programmed to operate as well as non-operable and/or non-operable devices, respectively.
# The device can also be programmed to operate as a security device. A security device can be programmed to have the device operate as a security device. A non-security device can be programmed to have the device operate as a non-security device.
# The invention may be carried out in a variety of manners. The invention is used with a security device that is not a security device, or with a security device that is a device intended to be used by a security device without the security device.
# In one embodiment of the invention, a method of operating a semiconductor manufacturing device is provided. The method includes the steps of: first, selecting a device that has a chip attached thereto as a security device; and then, if the security device has no chip attached thereto, selecting a device having a chip as a non-security device, and a non-security device having a chip attached thereto as a security device.
# In a more specific aspect, the invention may be useful with a security device that has a chip attached thereto as a non-security device. A security device may be programmed to have a chip attached thereto as a non-secure device without using the chip attached thereto, and without using the chip attached thereto, on the non-secure device.
# The invention may also be used with a non-security device that has a chip attached thereto as a security device.
# In one embodiment of the invention, the method includes the steps of: selecting an object having a chip attached thereto as a non-secure device; and then, if the object does not have a chip attached thereto, selecting a device having a chip as a security device.
# In another embodiment of the

# %%
print(res[0]['generated_text'])
# Out:
# The uprising of apple iphone users is the main topic of discussion in social networks. Apple's official iPhone forum has a huge amount of posts from users who want to ask iPhone users about their opinions and feelings about the iPhone revolution. For Apple, the iPhone is only important for its marketing, and users have little input in the iPhone product itself. It's also a fact that Apple's iPhone is very popular among users, and also has a lot of potential.
# How much Apple's iPhone is used? As an iPhone owner, your life is made easier in many ways. You can make it more convenient for yourself and your friends by getting cheap prices for your iPhone. You can save hundreds of dollars with cheap price services that help you to buy cheap iPhones at the best price possible. You can find many services that offer iPhone deals including from iPhone store to cheap iPhone apps. iPhone users are most likely to use and also spend much of time on their iPhones.
# With these tips, you can avoid the errors that can harm your iPhone’s reputation and even the chance of having a defective or faulty iPhone. Below, we will guide you through some of the most common mistakes when dealing with iPhone repair:
# There's no such thing as a free iPhone! No matter how much you spend, you always end up paying for something you didn't ask for. If you have been shopping for a brand-new iPhone, you probably found one at a store that seemed amazing, but it was too expensive. If you want to get a new iPhone, you need to do some research first to make sure you are getting the right phone for your needs.
# Many people are just as willing to buy a used iPhone as they are to use an old one. Apple is one of the most popular brands in the market for iPhone replacement, which means a lot of people are willing to buy a used iPhone instead. The best thing about a used iPhone that you can do is to contact the seller directly and ask them to ship you the phone they have in their possession.
# What to do if you can't find the right iPhone for you? You can do some simple online research to see which phones are available for sale. Once you know which iPhone is the best, you can go right to the website to sign up and buy it. It's simple, painless and hassle-free, and you will have a phone that fits your needs right off the bat.
#
# Apple iPhone Forum

# %%
with open('gpttext.txt', 'w') as f:
    f.writelines(res[0]['generated_text'])

# %%
# !python --version
# Out:
# Python 3.7.15
