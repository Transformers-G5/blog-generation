# %%
from keytotext import pipeline

# %%
nlp = pipeline("mrm8488/t5-base-finetuned-common_gen")
# Out:
# Downloading: 100%|██████████| 25.0/25.0 [00:00<00:00, 9.14kB/s]
# Downloading: 100%|██████████| 1.24k/1.24k [00:00<00:00, 301kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 nlp = pipeline("mrm8488/t5-base-finetuned-common_gen")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/g5-model/lib/python3.8/site-packages/keytotext/pipeline.py:95, in pipeline(task, model, tokenizer, use_cuda)
#      90         raise Exception(
#      91             "Please provided a PretrainedTokenizer "
#      92             "class or a path/identifier to a pretrained tokenizer."
#      93         )
#      94 if isinstance(tokenizer, (str, tuple)):
# ---> 95     tokenizer = AutoTokenizer.from_pretrained(tokenizer)
#      97 # Instantiate model if needed
#      98 if isinstance(model, str):
#
# ...

# %%
keywords = ['apple']
